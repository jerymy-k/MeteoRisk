# %%
import pandas as pd 
pd.set_option('display.max_rows', None)
pd.read_csv('./silver/meteo_features.csv')
# df.isnull().sum()
# df['city'].duplicated().sum()
# df['lat'].between(21, 36).all()
# df['lng'].between(-17, -1).all()
# df.dtypes
# df[['precipitation_sum', 'precipitation_probability_max']].describe()
# (df['precipitation_sum'] > 0).sum()
# Out:
#            date  temp_max  temp_min  precipitation_sum  \
# 0    2026-09-14      31.9      23.6                0.0
# 1    2026-09-15      28.5      22.2                0.0
# 2    2026-09-16      25.8      21.1                0.0
# 3    2026-09-17      25.7      19.9                0.0
# 4    2026-09-18      25.5      19.2                0.0
# 5    2026-09-19      28.3      20.0                0.0
# 6    2026-09-20      31.1      21.2                0.0
# 7    2026-09-14      29.5      22.5                0.0
# 8    2026-09-15      30.3      21.2                0.0
# 9    2026-09-16      26.8      18.2                0.0
# 10   2026-09-17      26.8      18.6                0.0
# 11   2026-09-18      28.5      19.0                0.0
# 12   2026-09-19      26.5      21.6                0.0
# 13   2026-09-20      26.0      22.0                0.0
# 14   2026-09-14      38.3      23.5                0.0
# 15   2026-09-15      35.2      24.0                0.0
# ...
